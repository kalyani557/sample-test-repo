# %% [markdown]
# <a href="https://colab.research.google.com/github/kalyani557/sample-test-repo/blob/yateen-sharma/pythonbasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [1, 2, 3, 4, 5, 6]

even = filter(lambda x: x % 2 == 0, numbers)

print(list(even))
# Out:
# [2, 4, 6]
